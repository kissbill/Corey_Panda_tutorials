# %%
import pandas as pd
import dtale

# survey_public_link = 'C:/Users/asusu/Documents/REPO/data/survey_results_public.csv'
# survey_schema_link = 'C:/Users/asusu/Documents/REPO/data/survey_results_schema.csv'

tap_Log_link= 'C:/Users/Erik_Dubrovszkij/Documents/Projects/Homee/Tap_Log_Export_20200221.csv'

df = pd.read_csv(tap_Log_link)
remove_nan_colm_data = df.dropna(axis='columns', how='all')
remove_nan_colm_data
# Out:
#        Milliseconds  timezoneOffset                      timestamp  DayOfYear  \
# 0     1230751126776         3600000  2008-12-31T20:18:46.776+01:00        366
# 1     1526304739951         7200000  2018-05-14T15:32:19.951+02:00        134
# 2     1526306116707         7200000  2018-05-14T15:55:16.707+02:00        134
# 3     1526318780295         7200000  2018-05-14T19:26:20.295+02:00        134
# 4     1526318804848         7200000  2018-05-14T19:26:44.848+02:00        134
# ...             ...             ...                            ...        ...
# 2691  1582145536113         3600000  2020-02-19T21:52:16.113+01:00         50
# 2692  1582145666519         3600000  2020-02-19T21:54:26.519+01:00         50
# 2693  1582219463357         3600000  2020-02-20T18:24:23.357+01:00         51
# 2694  1582223593459         3600000  2020-02-20T19:33:13.459+01:00         51
# 2695  1582277491877         3600000  2020-02-21T10:31:31.877+01:00         52
#
#       DayOfMonth  DayOfWeek  TimeOfDay   _id             cat1      cat2
# 0             31  Wednesday  20.312778  2903         Toltesek    PSVita
# 1             14     Monday  15.538611    10  Erkezes/Indulas  Dési Out
# 2             14     Monday  15.921111    11  Erkezes/Indulas   Dési In
# 3             14     Monday  19.438889    13            Aniko    Utazas
# 4             14     Monday  19.445556    14  Erkezes/Indulas  Dési Out
# ...          ...        ...        ...   ...              ...       ...
# 2691          19  Wednesday  21.871111  3144             Erik     Gamma
# 2692          19  Wednesday  21.907222  3145            Aniko    Utazas
# 2693          20   Thursday  18.406389  3146             Erik      Prog
# 2694          20   Thursday  19.553611  3147             Erik  Planning
# 2695          21     Friday  10.525278  3148             Erik     Gamma
#
# [2696 rows x 10 columns]

# %%
remove_nan_colm_data.drop(remove_nan_colm_data.columns[[0,1]],axis=1,inplace=True)

# %%
name = ['Aniko']
filtAniko = remove_nan_colm_data['cat1'].isin(name)
df_Aniko = remove_nan_colm_data.loc[filtAniko]
df_Aniko['cat2'].value_counts()
# Out:
# Beszelgetes    199
# Aktus          157
# VideoA         133
# Utazas         120
# Vita            57
# JatekA          53
# Kivanos         52
# Name: cat2, dtype: int64

# %%
d = dtale.show(df_Aniko)
d
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="http://EPHUBUDW0340:40000/dtale/iframe/8"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Exception on /charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# Exception on /charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# 2020-02-27 16:39:37,332 - ERROR    - Exception on /charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# 500 Internal Server Error: The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# 500 Internal Server Error: The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# 2020-02-27 16:39:37,336 - ERROR    - 500 Internal Server Error: The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# Exception on /charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# Exception on /charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# 2020-02-27 16:40:28,561 - ERROR    - Exception on /charts/_dash-update-component [POST]
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# 500 Internal Server Error: The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# 500 Internal Server Error: The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
# 2020-02-27 16:40:28,565 - ERROR    - 500 Internal Server Error: The server encountered an internal error and was unable to complete your request. Either the server is overloaded or there is an error in the application.
# Traceback (most recent call last):
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 2446, in wsgi_app
#     response = self.full_dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1951, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1820, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "c:\program files\python37\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1949, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "c:\program files\python37\lib\site-packages\flask\app.py", line 1935, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1459, in dispatch
#     response.set_data(self.callback_map[output]["callback"](*args))
#   File "c:\program files\python37\lib\site-packages\dash\dash.py", line 1339, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "c:\program files\python37\lib\site-packages\dtale\dash_application\views.py", line 328, in display_page
#     df = DATA[get_data_id(pathname)]
# KeyError: '8'
